# %% [markdown]
# ## As the Castro paper is only using the DC and classical monocytes from our atlas, making a UMAP of just these cells.

# %%
#load packages I need
import os
import tools
import scanpy as sc
import pandas as pd
import dandelion as ddl
from tqdm import tqdm
import matplotlib.pyplot as plt
import scanpy.external as sce
from matplotlib.pyplot import rc_context
import seaborn as sns

# %%
#set current directory 
os.chdir('/scratch/user/s4436039/scdata/Myeloid_Objects')
os.getcwd()
# Out:
# '/scratch/user/s4436039/scdata/Myeloid_Objects'

# %% [markdown]
# # Harmony (didn't end up using):

# %%
# read in data
data = sc.read_h5ad('NRclean_clustered2.h5ad')

# %%
data
# Out:
# AnnData object with n_obs × n_vars = 498023 × 1268
# ...

# %%
data.obs["NR_annotations_simple"].value_counts()
# Out:
# NR_annotations_simple
# Tissue resident macrophage           368421
# Classical monocytes                   57086
# non-classical monocytes               29255
# cDC2                                  17391
# KI-67+ Tissue resident macrophage     13020
# cDC1                                   6730
# mregDC                                 6120
# Name: count, dtype: int64

# %%
# subset out the DC and classical monocytes
data_DCM = data[data.obs["NR_annotations_simple"].isin(["cDC1","cDC2","mregDC","Classical monocytes"])]

# %%
data_DCM.obs["NR_annotations_simple"].value_counts()
# Out:
# NR_annotations_simple
# Classical monocytes    57086
# cDC2                   17391
# cDC1                    6730
# mregDC                  6120
# Name: count, dtype: int64

# %%
data_DCM
# Out:
# View of AnnData object with n_obs × n_vars = 87327 × 1268
# ...

# %% [markdown]
# ### Repeat neighbours and UMAP on subset

# %%
## Computing neighbourhood graph 
sc.pp.neighbors(data_DCM, n_neighbors=10, n_pcs=60)

# %%
sc.tl.umap(data_DCM, min_dist=0.3)

# %%
#plotting 
with plt.rc_context({"figure.figsize": (4, 4)}):
    sc.pl.umap(data_DCM, color=["NR_annotations_simple"], ncols=1, size=5, title="")

# %% [markdown]
# # Repeat with scvi object:

# %%
#show current directory 
os.chdir('/scratch/user/s4436039/scdata/Myeloid_Objects')
os.getcwd()
# Out:
# '/scratch/user/s4436039/scdata/Myeloid_Objects'

# %%
data_scvi = sc.read_h5ad('/scratch/user/s4436039/scdata/Myeloid_Objects/NRclean_scVI_Data.h5ad')

# %%
data_scvi
# Out:
# AnnData object with n_obs × n_vars = 498023 × 1264
#     obs: 'nCount_RNA', 'nFeature_RNA', 'sample_type', 'cancer_type', 'patient_id', 'sample_id', 'percent.mt', 'site', 'sample_type_major', 'cancer_subtype', 'integration_id', 'ident', 'dataset_id', 'Technology', 'NR_annotations_simple', 'sample_type_major2', 'cancer_with_H', 'cancer_broadest', 'patient_treatment', '_scvi_batch', '_scvi_labels'
#     var: 'name', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'hvg', 'integration_id_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
# subset out the DC and classical monocytes
data_DCM_scvi = data_scvi[data_scvi.obs["NR_annotations_simple"].isin(["cDC1","cDC2","mregDC","Classical monocytes"])]

# %%
# repeat without mregDC
data_DC1_2_M_scvi = data_scvi[data_scvi.obs["NR_annotations_simple"].isin(["cDC1","cDC2","Classical monocytes"])]

# %%
data_DCM_scvi.obs["NR_annotations_simple"].value_counts()
# Out:
# NR_annotations_simple
# Classical monocytes    57086
# cDC2                   17391
# cDC1                    6730
# mregDC                  6120
# Name: count, dtype: int64

# %%
data_DC1_2_M_scvi.obs["NR_annotations_simple"].value_counts()
# Out:
# NR_annotations_simple
# Classical monocytes    57086
# cDC2                   17391
# cDC1                    6730
# Name: count, dtype: int64

# %%
#check how many PCs in scvi object:
data_DCM_scvi.obsm["X_pca"].shape
# Out:
# (87327, 50)

# %%
#check how many PCs in scvi object:
data_DCM_scvi.obsm["X_scVI"].shape
# Out:
# (87327, 30)

# %%
#check how many PCs in scvi object:
data_DC1_2_M_scvi.obsm["X_scVI"].shape
# Out:
# (81207, 30)

# %%
# For scvi data, assign the new PCs to the standard PCA slot
data_DCM_scvi.obsm['X_pca'] = data_DCM_scvi.obsm['X_scVI']
# Out:
# /scratch/temp/14333408/ipykernel_2427343/2776056722.py:2: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.

# %%
# For scvi data, assign the new PCs to the standard PCA slot
data_DC1_2_M_scvi.obsm['X_pca'] = data_DC1_2_M_scvi.obsm['X_scVI']
# Out:
# /scratch/temp/14353534/ipykernel_1726737/4101479447.py:2: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.

# %%
#check how many PCs in scvi object:
data_DCM_scvi.obsm["X_pca"].shape
# Out:
# (87327, 30)

# %%
#check how many PCs in scvi object:
data_DC1_2_M_scvi.obsm["X_pca"].shape
# Out:
# (81207, 30)

# %%
## Computing neighbourhood graph 
sc.pp.neighbors(data_DCM_scvi, n_neighbors=10, n_pcs=30, use_rep="X_scVI")

# %%
## Computing neighbourhood graph 
sc.pp.neighbors(data_DC1_2_M_scvi, n_neighbors=10, n_pcs=30, use_rep="X_scVI")

# %%
sc.tl.umap(data_DCM_scvi, min_dist=0.3)

# %%
sc.tl.umap(data_DC1_2_M_scvi, min_dist=0.3)

# %%
custom_palette = [
    "#0000a2",  # classical mono
    "#a74f3f",  # cDC1
    "#e9c716",  # cDC2
    "#50ad9f",  # mregDC
]

# %%
sc.set_figure_params(dpi=80, dpi_save=700, vector_friendly=True, format='svg')

# %%
#plotting 
with plt.rc_context({"figure.figsize": (4, 4)}):
    sc.pl.umap(data_DCM_scvi, color=["NR_annotations_simple"], ncols=1, size=5, title="", palette=custom_palette, save="Nikita-Castro-DCM-UMAP.svg")
# Out:
# WARNING: saving figure to file figures/umapNikita-Castro-DCM-UMAP.svg

# %% [markdown]
# ## Editing to match Castro colours:

# %%
custom_palette = [
    "#50ad9f",  # classical mono
    "#d5d5d5",  # cDC1
    "#fa3740",  # cDC2
    "#22577a",  # mregDC
]

# %%
sc.set_figure_params(dpi=80, dpi_save=700, vector_friendly=True, format='svg')

# %%
#plotting 
with plt.rc_context({"figure.figsize": (4, 4)}):
    sc.pl.umap(data_DCM_scvi, color=["NR_annotations_simple"], ncols=1, size=5, title="", palette=custom_palette, save="Nikita-Castro-DCM-UMAP-update.svg")
# Out:
# WARNING: saving figure to file figures/umapNikita-Castro-DCM-UMAP-update.svg

# %%
custom_palette = [
    "#50ad9f",  # classical mono
    "#d5d5d5",  # cDC1
    "#fa3740",  # cDC2
]

# %%
sc.set_figure_params(dpi=80, dpi_save=700, vector_friendly=True, format='svg')

# %%
#plotting 
with plt.rc_context({"figure.figsize": (4, 4)}):
    sc.pl.umap(data_DC1_2_M_scvi, color=["NR_annotations_simple"], ncols=1, size=5, title="", palette=custom_palette, save="Nikita-Castro-DC1-DC2-Mono.svg")
# Out:
# WARNING: saving figure to file figures/umapNikita-Castro-DC1-DC2-Mono.svg

# %% [markdown]
# ## Making marker plot to go with Castro UMAP:

# %%
custom_order = ["cDC1", "cDC2", "Classical monocytes"]

# %%
markers = ["CLEC9A","CD1C","CCR7","CD14"]

# %%
markers = ["CLEC9A","CD1C","CD14"]

# %%
sc.pl.dotplot(data_DCM_scvi, markers, groupby="NR_annotations_simple", categories_order=custom_order, standard_scale="var")

# %%
sc.set_figure_params(dpi=80, dpi_save=700, vector_friendly=True, format='svg')

# %%
sc.pl.dotplot(data_DC1_2_M_scvi, markers, groupby="NR_annotations_simple", categories_order=custom_order, standard_scale="var", save="_Nikita-Castro-DC1-DC2-Mono.svg")
# Out:
# WARNING: saving figure to file figures/dotplot__Nikita-Castro-DC1-DC2-Mono.svg

# %%
custom_order = ["cDC1", "cDC2", "mregDC", "Classical monocytes"]

# %%
sc.pl.matrixplot(data_DCM_scvi, markers, groupby="NR_annotations_simple", standard_scale="var", categories_order=custom_order)

# %%
from matplotlib.colors import LinearSegmentedColormap

# %%
# Define gradient
custom_gradient = LinearSegmentedColormap.from_list(
    "custom_gradient", ["#315677", "white", "#E64A49"] 
)

# %%
sc.pl.matrixplot(data_DCM_scvi, markers, groupby="NR_annotations_simple", standard_scale="var", categories_order=custom_order, cmap = custom_gradient)

# %%
sc.pl.matrixplot(data_DC1_2_M_scvi, markers, groupby="NR_annotations_simple", standard_scale="var", categories_order=custom_order, cmap = custom_gradient, save="_Nikita-Castro-DC1-DC2-Mono.svg")
# Out:
# WARNING: saving figure to file figures/matrixplot__Nikita-Castro-DC1-DC2-Mono.svg

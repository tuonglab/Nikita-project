# %% [markdown]
# ##### Steps for reading in dataset (following download), initial QC, dim reduction/clustering and saving out the myeloid cluster for **GSE158803**
#
# file previously downloaded:
# * GSE158803_RAW.tar
#
# unzipped using
# ``` bash
# tar -xvf GSE158803_RAW.tar
# ```
#
# This gave the following files:
# * GSM4810687_brainmet_TCR_filtered_contig_annotations.csv.gz
# * GSM4810687_brainmet_barcodes.tsv.gz
# * GSM4810687_brainmet_features.tsv.gz
# * GSM4810687_brainmet_matrix.mtx.gz
# * GSM4810688_livmet1_barcodes.tsv.gz
# * GSM4810688_livmet1_features.tsv.gz
# * GSM4810688_livmet1_matrix.mtx.gz
# * GSM4810689_livmet1_CD45_barcodes.tsv.gz
# * GSM4810689_livmet1_CD45_features.tsv.gz
# * GSM4810689_livmet1_CD45_matrix.mtx.gz
# * GSM4810690_livmet2_barcodes.tsv.gz
# * GSM4810690_livmet2_features.tsv.gz
# * GSM4810690_livmet2_matrix.mtx.gz
# * GSM4810691_livmet2_CD45_barcodes.tsv.gz
# * GSM4810691_livmet2_CD45_features.tsv.gz
# * GSM4810691_livmet2_CD45_matrix.mtx.gz
# * GSM4810692_ovarian_hashing_info.csv.gz
# * GSM4810693_uveal_melanoma_barcodes.tsv.gz
# * GSM4810693_uveal_melanoma_features.tsv.gz
# * GSM4810693_uveal_melanoma_matrix.mtx.gz
# * GSM4810694_mouse1_barcodes.tsv.gz
# * GSM4810694_mouse1_features.tsv.gz
# * GSM4810694_mouse1_matrix.mtx.gz
# * GSM4810695_mouse2_barcodes.tsv.gz
# * GSM4810695_mouse2_features.tsv.gz
# * GSM4810695_mouse2_matrix.mtx.gz
# * GSM4810696_mouse_Tcell_TCR_filtered_contig_annotations.csv.gz
# * GSM4810696_mouse_Tcell_barcodes.tsv.gz
# * GSM4810696_mouse_Tcell_features.tsv.gz
# * GSM4810696_mouse_Tcell_matrix.mtx.gz
#
# Dataset should contain:
# * 2 human uveal melanoma cancers
# * 1 human OC
# * 1 human uveal melanoma liver met
# * 1 human NSCLC brain met (includes TCR)
# * 2 humans head and neck cancers
# * 2 mouse CRC
#
# Not using mouse or TCR (moved to seperate folder)
#
# Decided to exclude dataset as data not all in the correct format (eg. ovarian sample)
